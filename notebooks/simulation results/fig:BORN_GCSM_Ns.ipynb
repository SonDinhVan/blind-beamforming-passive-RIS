# %%
import numpy as np
import matplotlib.pyplot as plt

from modules import node, system, sensing
from modules import optimization as opt
from configs import config

noise_power = config.NOISE_POWER

# %%
tx = node.TX(x=0, y=0, z=10)
rx = node.RX(x=50, y=50, z=1.5)
ris = node.RIS(x=10, y=50, z=2, N=100)
sys = system.System(tx, ris, rx)

is_los = False
n_loop = 5000

figure_name = f'fig_BORN_GCSM_{ris.N}_LOS' if is_los else f'fig_BORN_GCSM_{ris.N}_NLOS.pdf'

# %%
N_samples = 1000
B = 1000
all_born_1000 = []

for i in range(n_loop):
    print("---------------------------")
    print(f"Computing LOOP {i}")
    sys.gen_channels(is_los=is_los)

    # Stage 0: sending samples and collect observation:
    X = np.zeros(shape=(sys.ris.N, N_samples))
    y = np.zeros(shape=(N_samples, 1))
    for j in range(N_samples):
        # generate a random ris setting
        sys.ris.set_random_binary_phase_shifts()
        x = sys.ris.vector_x
        X[:, j] = x.flatten()
        y[j] = sys.cal_snr() - sys.c_true

    sens = sensing.Sensing(B=B, N=sys.ris.N)
    M_est, w_est, _ = sens.solve(X=X, y=y, convergence_plot=False) # Stage 1: sensing
    M_est_proj = sens.project_to_psd_lowrank(M_est, r=2) # projection to low rank
    sys.ris.vector_x = opt.solve_our_optimization(M_est_proj, w_est) # Stage 2: optimization
    sys.ris.theta = np.arccos(sys.ris.vector_x)
    born = 10 * np.log10(sys.cal_snr())
    
    all_born_1000.append(born)
# Out:
# ---------------------------
# Computing LOOP 0
# Variance of the last 5 estimates = 8446714570545.544
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 1
# Variance of the last 5 estimates = 1334020184142.1497
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 2
# Variance of the last 5 estimates = 237761422773.4767
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 3
# Variance of the last 5 estimates = 559391446523.1501
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4
# Variance of the last 5 estimates = 32110600931.696815
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 5
# Variance of the last 5 estimates = 855725952512.1995
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 6
# Variance of the last 5 estimates = 556533220966.9552
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 7
# Variance of the last 5 estimates = 1006828248459.9988
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 8
# Variance of the last 5 estimates = 22397466188.913673
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 9
# Variance of the last 5 estimates = 47464974499.836
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 10
# Variance of the last 5 estimates = 20985690716.092945
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 11
# Variance of the last 5 estimates = 20501317576.48629
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 12
# Variance of the last 5 estimates = 170758867430.38452
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 13
# Variance of the last 5 estimates = 568238242285.0181
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 14
# Variance of the last 5 estimates = 4045628076781.983
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 15
# Variance of the last 5 estimates = 575775238678.4257
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 16
# Variance of the last 5 estimates = 559391549931.584
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 17
# Variance of the last 5 estimates = 9731619496.393002
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 18
# Variance of the last 5 estimates = 93109837002.40671
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 19
# Variance of the last 5 estimates = 555975704879.9418
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 20
# Variance of the last 5 estimates = 1022489927384.4596
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 21
# Variance of the last 5 estimates = 78995139595.95482
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 22
# Variance of the last 5 estimates = 193950557718.95184
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 23
# Variance of the last 5 estimates = 131286835468.53035
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 24
# Variance of the last 5 estimates = 157573037358.82678
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 25
# Variance of the last 5 estimates = 22052656639.455925
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 26
# Variance of the last 5 estimates = 64321086589.19472
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 27
# Variance of the last 5 estimates = 629462400090.2063
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 28
# Variance of the last 5 estimates = 53489351185.59922
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 29
# Variance of the last 5 estimates = 1273795178012.127
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 30
# Variance of the last 5 estimates = 1472844923920.4436
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 31
# Variance of the last 5 estimates = 1921509673935.269
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 32
# Variance of the last 5 estimates = 674409550865.6711
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 33
# Variance of the last 5 estimates = 592105315453.5896
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 34
# Variance of the last 5 estimates = 304829210732.6969
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 35
# Variance of the last 5 estimates = 359899436262.1589
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 36
# Variance of the last 5 estimates = 377939215823.5363
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 37
# Variance of the last 5 estimates = 558954557186.0059
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 38
# Variance of the last 5 estimates = 530465732746.8615
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 39
# Variance of the last 5 estimates = 167618689358.53403
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 40
# Variance of the last 5 estimates = 172325329126.18146
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 41
# Variance of the last 5 estimates = 327595829662.9028
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 42
# Variance of the last 5 estimates = 187986934054.8362
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 43
# Variance of the last 5 estimates = 1244159897544.7383
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 44
# Variance of the last 5 estimates = 200204509246.00787
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 45
# Variance of the last 5 estimates = 166158118032.03857
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 46
# Variance of the last 5 estimates = 123548281864.56909
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 47
# Variance of the last 5 estimates = 366524613615.3207
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 48
# Variance of the last 5 estimates = 19182952873.298424
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 49
# Variance of the last 5 estimates = 1215067608306.1528
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 50
# Variance of the last 5 estimates = 37616570053.3253
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 51
# Variance of the last 5 estimates = 152642467706.63333
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 52
# Variance of the last 5 estimates = 77289552950.82358
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 53
# Variance of the last 5 estimates = 697922061909.8518
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 54
# Variance of the last 5 estimates = 107490840957.54623
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 55
# Variance of the last 5 estimates = 197636811441.9791
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 56
# Variance of the last 5 estimates = 373265811217.0519
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 57
# Variance of the last 5 estimates = 489957804420.4093
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 58
# Variance of the last 5 estimates = 30780683812.61856
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 59
# Variance of the last 5 estimates = 52610583204.070274
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 60
# Variance of the last 5 estimates = 686611803220.3544
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 61
# Variance of the last 5 estimates = 210911653578.40247
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 62
# Variance of the last 5 estimates = 1962672005959.808
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 63
# Variance of the last 5 estimates = 785696285763.229
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 64
# Variance of the last 5 estimates = 55785952006.941505
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 65
# Variance of the last 5 estimates = 625484087283.5173
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 66
# Variance of the last 5 estimates = 4657806213267.8545
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 67
# Variance of the last 5 estimates = 36720735638.91472
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 68
# Variance of the last 5 estimates = 127751963843.98154
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 69
# Variance of the last 5 estimates = 925338085027.902
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 70
# Variance of the last 5 estimates = 134211936791.75203
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 71
# Variance of the last 5 estimates = 95754366016.16377
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 72
# Variance of the last 5 estimates = 246686176982.69684
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 73
# Variance of the last 5 estimates = 68790383802.56465
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 74
# Variance of the last 5 estimates = 626959232530.527
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 75
# Variance of the last 5 estimates = 86699212332.68321
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 76
# Variance of the last 5 estimates = 150902887538.07574
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 77
# Variance of the last 5 estimates = 102401383752.00755
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 78
# Variance of the last 5 estimates = 42265185506.968216
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 79
# Variance of the last 5 estimates = 670528455509.47
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 80
# Variance of the last 5 estimates = 427466127497.9964
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 81
# Variance of the last 5 estimates = 31144103494.898354
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 82
# Variance of the last 5 estimates = 78984030477.55759
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 83
# Variance of the last 5 estimates = 159457073616.48892
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 84
# Variance of the last 5 estimates = 72557337319.95093
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 85
# Variance of the last 5 estimates = 1571978108004.9045
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 86
# Variance of the last 5 estimates = 3166445754061.1733
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 87
# Variance of the last 5 estimates = 685000503928.6023
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 88
# Variance of the last 5 estimates = 266651233464.1438
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 89
# Variance of the last 5 estimates = 84450588376.91824
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 90
# Variance of the last 5 estimates = 792647861806.9326
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 91
# Variance of the last 5 estimates = 86510951024.51053
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 92
# Variance of the last 5 estimates = 701693215139.9775
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 93
# Variance of the last 5 estimates = 742004126141.184
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 94
# Variance of the last 5 estimates = 3015101789035.9116
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 95
# Variance of the last 5 estimates = 71751677330.82278
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 96
# Variance of the last 5 estimates = 1611000558305.523
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 97
# Variance of the last 5 estimates = 12332479628603.953
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 98
# Variance of the last 5 estimates = 3826925253.8628135
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 99
# Variance of the last 5 estimates = 1137113675015.5356
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 100
# Variance of the last 5 estimates = 188623950826.52808
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 101
# Variance of the last 5 estimates = 97232184129.15524
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 102
# Variance of the last 5 estimates = 89468958409.1543
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 103
# Variance of the last 5 estimates = 191424093290.42975
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 104
# Variance of the last 5 estimates = 1406381684841.8757
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 105
# Variance of the last 5 estimates = 68114266730.31758
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 106
# Variance of the last 5 estimates = 527722514806.3179
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 107
# Variance of the last 5 estimates = 1190711273270.5835
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 108
# Variance of the last 5 estimates = 626992758981.8064
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 109
# Variance of the last 5 estimates = 73807070087.93178
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 110
# Variance of the last 5 estimates = 176465890579.33224
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 111
# Variance of the last 5 estimates = 1076580808165.948
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 112
# Variance of the last 5 estimates = 15609092297.048956
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 113
# Variance of the last 5 estimates = 12655281292.431095
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 114
# Variance of the last 5 estimates = 619216055717.2963
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 115
# Variance of the last 5 estimates = 157745573154.41995
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 116
# Variance of the last 5 estimates = 414815652117.363
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 117
# Variance of the last 5 estimates = 827371050814.7542
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 118
# Variance of the last 5 estimates = 413183869252.90393
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 119
# Variance of the last 5 estimates = 202251540452.77466
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 120
# Variance of the last 5 estimates = 47434539996.338455
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 121
# Variance of the last 5 estimates = 58272091041.56106
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 122
# Variance of the last 5 estimates = 99054360446.72246
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 123
# Variance of the last 5 estimates = 260199777728.13892
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 124
# Variance of the last 5 estimates = 102087808736.41023
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 125
# Variance of the last 5 estimates = 36278645463.72615
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 126
# Variance of the last 5 estimates = 124792370258.22823
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 127
# Variance of the last 5 estimates = 186845628505.20508
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 128
# Variance of the last 5 estimates = 85941282169.49347
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 129
# Variance of the last 5 estimates = 127087478432.33028
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 130
# Variance of the last 5 estimates = 182572563409.79214
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 131
# Variance of the last 5 estimates = 49030542775.59848
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 132
# Variance of the last 5 estimates = 987768074783.8308
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 133
# Variance of the last 5 estimates = 37501453280.29912
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 134
# Variance of the last 5 estimates = 667318619889.4111
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 135
# Variance of the last 5 estimates = 276562476727.3914
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 136
# Variance of the last 5 estimates = 28627871650.97088
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 137
# Variance of the last 5 estimates = 185897373775.1794
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 138
# Variance of the last 5 estimates = 697958583098.1877
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 139
# Variance of the last 5 estimates = 1353030217697.909
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 140
# Variance of the last 5 estimates = 459780462402.3721
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 141
# Variance of the last 5 estimates = 490678845496.02185
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 142
# Variance of the last 5 estimates = 185757894345.08328
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 143
# Variance of the last 5 estimates = 422939068393.0246
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 144
# Variance of the last 5 estimates = 229844559472.2146
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 145
# Variance of the last 5 estimates = 19846762959.614815
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 146
# Variance of the last 5 estimates = 14642692293.752598
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 147
# Variance of the last 5 estimates = 200741328946.52954
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 148
# Variance of the last 5 estimates = 87409988104.82597
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 149
# Variance of the last 5 estimates = 770678724367.5388
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 150
# Variance of the last 5 estimates = 861415073477.807
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 151
# Variance of the last 5 estimates = 23558323621.638165
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 152
# Variance of the last 5 estimates = 507562380968.89124
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 153
# Variance of the last 5 estimates = 35189801984.17525
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 154
# Variance of the last 5 estimates = 47080048232.81202
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 155
# Variance of the last 5 estimates = 231999194974.37662
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 156
# Variance of the last 5 estimates = 45288772676.758804
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 157
# Variance of the last 5 estimates = 6455478166260.353
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 158
# Variance of the last 5 estimates = 5981588702037.612
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 159
# Variance of the last 5 estimates = 248267805529.05615
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 160
# Variance of the last 5 estimates = 170031063395.3941
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 161
# Variance of the last 5 estimates = 356344448850.4912
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 162
# Variance of the last 5 estimates = 2553796323774.1245
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 163
# Variance of the last 5 estimates = 201605932542.2602
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 164
# Variance of the last 5 estimates = 4200737932.6334395
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 165
# Variance of the last 5 estimates = 99183999015.18729
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 166
# Variance of the last 5 estimates = 371754658386.49493
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 167
# Variance of the last 5 estimates = 46756338741.25123
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 168
# Variance of the last 5 estimates = 122781554973.1597
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 169
# Variance of the last 5 estimates = 33158824018.51593
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 170
# Variance of the last 5 estimates = 112573813023.01978
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 171
# Variance of the last 5 estimates = 113932089579.9377
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 172
# Variance of the last 5 estimates = 480785933176.7365
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 173
# Variance of the last 5 estimates = 8780705162.684778
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 174
# Variance of the last 5 estimates = 25326319473.70697
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 175
# Variance of the last 5 estimates = 23688641191.645916
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 176
# Variance of the last 5 estimates = 184153636237.554
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 177
# Variance of the last 5 estimates = 17120350103.247639
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 178
# Variance of the last 5 estimates = 436899400829.8285
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 179
# Variance of the last 5 estimates = 32298944551.150444
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 180
# Variance of the last 5 estimates = 484583190929.48474
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 181
# Variance of the last 5 estimates = 254071274362.98764
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 182
# Variance of the last 5 estimates = 1377649895557.8215
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 183
# Variance of the last 5 estimates = 195005485327.3929
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 184
# Variance of the last 5 estimates = 143249042097.57193
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 185
# Variance of the last 5 estimates = 24224392027.45381
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 186
# Variance of the last 5 estimates = 85221133290.50699
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 187
# Variance of the last 5 estimates = 1338486581866.899
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 188
# Variance of the last 5 estimates = 93388960874.53848
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 189
# Variance of the last 5 estimates = 334517684438.70325
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 190
# Variance of the last 5 estimates = 1225488650686.4946
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 191
# Variance of the last 5 estimates = 996258701269.5632
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 192
# Variance of the last 5 estimates = 66915079980.243935
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 193
# Variance of the last 5 estimates = 145684916098.69357
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 194
# Variance of the last 5 estimates = 1162147177438.4126
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 195
# Variance of the last 5 estimates = 110684005976.44492
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 196
# Variance of the last 5 estimates = 253848292320.95752
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 197
# Variance of the last 5 estimates = 355155131982.26874
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 198
# Variance of the last 5 estimates = 1215285010915.4673
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 199
# Variance of the last 5 estimates = 69346594142.97714
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 200
# Variance of the last 5 estimates = 34868784881.9872
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 201
# Variance of the last 5 estimates = 84389638353.82033
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 202
# Variance of the last 5 estimates = 125736190553.95328
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 203
# Variance of the last 5 estimates = 27803552225.042164
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 204
# Variance of the last 5 estimates = 66626765510.33572
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 205
# Variance of the last 5 estimates = 174302961032.68338
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 206
# Variance of the last 5 estimates = 160253207931.23358
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 207
# Variance of the last 5 estimates = 140247073617.24582
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 208
# Variance of the last 5 estimates = 248390081473.5074
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 209
# Variance of the last 5 estimates = 133530761080.29874
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 210
# Variance of the last 5 estimates = 43861308354.04085
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 211
# Variance of the last 5 estimates = 58815738633.16826
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 212
# Variance of the last 5 estimates = 226759949629.51178
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 213
# Variance of the last 5 estimates = 397346573281.2499
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 214
# Variance of the last 5 estimates = 259310514680.56622
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 215
# Variance of the last 5 estimates = 593784479726.1335
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 216
# Variance of the last 5 estimates = 13116213443.538773
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 217
# Variance of the last 5 estimates = 15079435261.118479
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 218
# Variance of the last 5 estimates = 50078006774.77559
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 219
# Variance of the last 5 estimates = 148278698313.33612
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 220
# Variance of the last 5 estimates = 52916830703.020065
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 221
# Variance of the last 5 estimates = 1562226205173.5625
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 222
# Variance of the last 5 estimates = 68925961089.6033
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 223
# Variance of the last 5 estimates = 257839775075.24365
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 224
# Variance of the last 5 estimates = 271591578292.15762
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 225
# Variance of the last 5 estimates = 3406609552910.478
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 226
# Variance of the last 5 estimates = 108566498131.93683
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 227
# Variance of the last 5 estimates = 218224180945.1884
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 228
# Variance of the last 5 estimates = 128102793735.15288
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 229
# Variance of the last 5 estimates = 139760746945.0721
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 230
# Variance of the last 5 estimates = 113788069203.70662
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 231
# Variance of the last 5 estimates = 282824300955.3838
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 232
# Variance of the last 5 estimates = 172802824869.49652
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 233
# Variance of the last 5 estimates = 264684051005.02472
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 234
# Variance of the last 5 estimates = 724563558218.1062
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 235
# Variance of the last 5 estimates = 941139889431.6852
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 236
# Variance of the last 5 estimates = 85003314198.93283
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 237
# Variance of the last 5 estimates = 7673515375.722705
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 238
# Variance of the last 5 estimates = 44491107378.89055
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 239
# Variance of the last 5 estimates = 27513685151.081535
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 240
# Variance of the last 5 estimates = 150235009857.55826
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 241
# Variance of the last 5 estimates = 3162244661595.825
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 242
# Variance of the last 5 estimates = 149549278065.16226
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 243
# Variance of the last 5 estimates = 101086039132.37494
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 244
# Variance of the last 5 estimates = 284470399193.7894
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 245
# Variance of the last 5 estimates = 24411272553.96711
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 246
# Variance of the last 5 estimates = 22185614917.102795
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 247
# Variance of the last 5 estimates = 65224248350.978806
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 248
# Variance of the last 5 estimates = 103893042619.28877
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 249
# Variance of the last 5 estimates = 66857969387.024536
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 250
# Variance of the last 5 estimates = 591314261389.0282
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 251
# Variance of the last 5 estimates = 1826897335282.267
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 252
# Variance of the last 5 estimates = 80360340207.26782
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 253
# Variance of the last 5 estimates = 692245846837.9402
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 254
# Variance of the last 5 estimates = 1990722426902.3938
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 255
# Variance of the last 5 estimates = 42569029253.23157
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 256
# Variance of the last 5 estimates = 111720558993.97647
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 257
# Variance of the last 5 estimates = 3042147082949.492
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 258
# Variance of the last 5 estimates = 1467677882892.894
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 259
# Variance of the last 5 estimates = 278170660116.1708
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 260
# Variance of the last 5 estimates = 259255272906.6795
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 261
# Variance of the last 5 estimates = 1426773873093.3762
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 262
# Variance of the last 5 estimates = 507728376089.71497
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 263
# Variance of the last 5 estimates = 10852554199.928745
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 264
# Variance of the last 5 estimates = 323546198629.8921
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 265
# Variance of the last 5 estimates = 326492041627.6421
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 266
# Variance of the last 5 estimates = 51076229206.500824
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 267
# Variance of the last 5 estimates = 151662699043.60043
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 268
# Variance of the last 5 estimates = 382837914718.888
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 269
# Variance of the last 5 estimates = 3229733381121.6875
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 270
# Variance of the last 5 estimates = 350442633773.9208
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 271
# Variance of the last 5 estimates = 73981324617.01375
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 272
# Variance of the last 5 estimates = 98975192743.83557
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 273
# Variance of the last 5 estimates = 259889599888.4417
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 274
# Variance of the last 5 estimates = 663806841284.7506
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 275
# Variance of the last 5 estimates = 375269069759.71765
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 276
# Variance of the last 5 estimates = 399397246099.97253
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 277
# Variance of the last 5 estimates = 74288632968.88223
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 278
# Variance of the last 5 estimates = 1451326548554.4924
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 279
# Variance of the last 5 estimates = 220541366403.32245
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 280
# Variance of the last 5 estimates = 405908144948.78107
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 281
# Variance of the last 5 estimates = 120373857319.32295
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 282
# Variance of the last 5 estimates = 58631270534.66313
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 283
# Variance of the last 5 estimates = 82017273504.84595
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 284
# Variance of the last 5 estimates = 2557671783920.4585
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 285
# Variance of the last 5 estimates = 95137331227.52475
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 286
# Variance of the last 5 estimates = 355904539256.1605
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 287
# Variance of the last 5 estimates = 1802588989447.1763
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 288
# Variance of the last 5 estimates = 244115432669.6744
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 289
# Variance of the last 5 estimates = 32676175986.11323
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 290
# Variance of the last 5 estimates = 1662389306048.2996
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 291
# Variance of the last 5 estimates = 86632985762.39388
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 292
# Variance of the last 5 estimates = 151452821224.86035
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 293
# Variance of the last 5 estimates = 1045774861783.9836
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 294
# Variance of the last 5 estimates = 157598947791.6467
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 295
# Variance of the last 5 estimates = 293165285352.26416
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 296
# Variance of the last 5 estimates = 1329829131758.233
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 297
# Variance of the last 5 estimates = 69204444364.15865
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 298
# Variance of the last 5 estimates = 56382607641.82085
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 299
# Variance of the last 5 estimates = 215126506640.40384
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 300
# Variance of the last 5 estimates = 218135434014.52377
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 301
# Variance of the last 5 estimates = 78480186194.86166
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 302
# Variance of the last 5 estimates = 52438690462.97646
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 303
# Variance of the last 5 estimates = 247204108975.10205
# ...
# ---------------------------
# Computing LOOP 4900
# Variance of the last 5 estimates = 2485909810259.135
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4901
# Variance of the last 5 estimates = 609435765429.1779
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4902
# Variance of the last 5 estimates = 113458828763.59338
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4903
# Variance of the last 5 estimates = 110041444704.4497
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4904
# Variance of the last 5 estimates = 133370803494.44832
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4905
# Variance of the last 5 estimates = 1735864182433.7632
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4906
# Variance of the last 5 estimates = 31657747077.680992
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4907
# Variance of the last 5 estimates = 15007952420.525227
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4908
# Variance of the last 5 estimates = 17462577881.53692
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4909
# Variance of the last 5 estimates = 288201745748.95416
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4910
# Variance of the last 5 estimates = 1188921259509.4014
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4911
# Variance of the last 5 estimates = 803734745941.8011
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4912
# Variance of the last 5 estimates = 15284172139.559925
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4913
# Variance of the last 5 estimates = 566695140893.4432
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4914
# Variance of the last 5 estimates = 61759549065.94084
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4915
# Variance of the last 5 estimates = 169902086536.99704
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4916
# Variance of the last 5 estimates = 40820838299.23381
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4917
# Variance of the last 5 estimates = 137514352345.9105
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4918
# Variance of the last 5 estimates = 95178414173.78375
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4919
# Variance of the last 5 estimates = 128899797656.96133
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4920
# Variance of the last 5 estimates = 499231609933.09393
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4921
# Variance of the last 5 estimates = 173450573782.93243
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4922
# Variance of the last 5 estimates = 3164709703478.987
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4923
# Variance of the last 5 estimates = 5101585107486.331
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4924
# Variance of the last 5 estimates = 1147781151037.5457
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4925
# Variance of the last 5 estimates = 2111423869469.4812
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4926
# Variance of the last 5 estimates = 61389990065.91811
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4927
# Variance of the last 5 estimates = 181086764951.70215
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4928
# Variance of the last 5 estimates = 406214506872.8495
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4929
# Variance of the last 5 estimates = 39268547718.03998
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4930
# Variance of the last 5 estimates = 6688169889.108003
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4931
# Variance of the last 5 estimates = 407911688001.0775
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4932
# Variance of the last 5 estimates = 30446898904.248158
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4933
# Variance of the last 5 estimates = 1691933518491.522
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4934
# Variance of the last 5 estimates = 10712348503.84444
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4935
# Variance of the last 5 estimates = 49525690147.191444
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4936
# Variance of the last 5 estimates = 1232955384455.5303
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4937
# Variance of the last 5 estimates = 1027875289138.0859
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4938
# Variance of the last 5 estimates = 223215630004.15314
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4939
# Variance of the last 5 estimates = 218272840140.846
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4940
# Variance of the last 5 estimates = 125012326534.71469
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4941
# Variance of the last 5 estimates = 328923917379.2709
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4942
# Variance of the last 5 estimates = 522656320989.08984
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4943
# Variance of the last 5 estimates = 159517873035.06256
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4944
# Variance of the last 5 estimates = 132525624270.7106
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4945
# Variance of the last 5 estimates = 101241929156.2781
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4946
# Variance of the last 5 estimates = 464590229700.57196
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4947
# Variance of the last 5 estimates = 114033371899.55843
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4948
# Variance of the last 5 estimates = 46436637605.426636
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4949
# Variance of the last 5 estimates = 33991668277.180458
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4950
# Variance of the last 5 estimates = 742574556555.1759
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4951
# Variance of the last 5 estimates = 163534665151.60153
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4952
# Variance of the last 5 estimates = 126513417425.10925
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4953
# Variance of the last 5 estimates = 46708077105.219284
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4954
# Variance of the last 5 estimates = 668905743751.4792
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4955
# Variance of the last 5 estimates = 442201682365.57385
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4956
# Variance of the last 5 estimates = 3204417612454.5684
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4957
# Variance of the last 5 estimates = 11723032819.072327
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4958
# Variance of the last 5 estimates = 71607255518.49904
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4959
# Variance of the last 5 estimates = 111085807909.20847
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4960
# Variance of the last 5 estimates = 399589351527.3382
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4961
# Variance of the last 5 estimates = 131645128865.77776
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4962
# Variance of the last 5 estimates = 174611363212.55643
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4963
# Variance of the last 5 estimates = 233302055319.89996
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4964
# Variance of the last 5 estimates = 909639918230.5013
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4965
# Variance of the last 5 estimates = 17572718426.165863
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4966
# Variance of the last 5 estimates = 26634093997.029137
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4967
# Variance of the last 5 estimates = 338770090557.3579
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4968
# Variance of the last 5 estimates = 643410703152.1648
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4969
# Variance of the last 5 estimates = 181367925955.59717
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4970
# Variance of the last 5 estimates = 111302971420.04292
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4971
# Variance of the last 5 estimates = 3587500561482.108
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4972
# Variance of the last 5 estimates = 410069360973.83704
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4973
# Variance of the last 5 estimates = 11966101057.033041
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4974
# Variance of the last 5 estimates = 327734402893.5994
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4975
# Variance of the last 5 estimates = 94584475431.95853
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4976
# Variance of the last 5 estimates = 729590352971.0349
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4977
# Variance of the last 5 estimates = 1052956807569.5898
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4978
# Variance of the last 5 estimates = 136163511345.30823
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4979
# Variance of the last 5 estimates = 80104949009.34319
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4980
# Variance of the last 5 estimates = 13100931103.724493
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4981
# Variance of the last 5 estimates = 540135084041.7069
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4982
# Variance of the last 5 estimates = 98854261776.39975
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4983
# Variance of the last 5 estimates = 19767120708.225945
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4984
# Variance of the last 5 estimates = 181329990612.93008
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4985
# Variance of the last 5 estimates = 271449218479.3416
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4986
# Variance of the last 5 estimates = 3826445029.4537873
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4987
# Variance of the last 5 estimates = 67878957575.11354
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4988
# Variance of the last 5 estimates = 185651795297.3864
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4989
# Variance of the last 5 estimates = 15632854209.369755
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4990
# Variance of the last 5 estimates = 2275959190886.292
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4991
# Variance of the last 5 estimates = 13877413098.44328
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4992
# Variance of the last 5 estimates = 70533331193.34021
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4993
# Variance of the last 5 estimates = 70078562317.42819
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4994
# Variance of the last 5 estimates = 62568733746.67507
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4995
# Variance of the last 5 estimates = 5174018622489.357
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4996
# Variance of the last 5 estimates = 200965635072.89606
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4997
# Variance of the last 5 estimates = 20006566779.024334
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4998
# Variance of the last 5 estimates = 279568861340.2983
# Consider to increase the batch size or number of samples.
# ---------------------------
# Computing LOOP 4999
# Variance of the last 5 estimates = 14659573101.308376
# Consider to increase the batch size or number of samples.

# %%
N_samples = 3000
B = 1000
all_born_3000 = []

for i in range(n_loop):
    print("---------------------------")
    print(f"Computing LOOP {i}")
    sys.gen_channels(is_los=is_los)

    # Stage 0: sending samples and collect observation:
    X = np.zeros(shape=(sys.ris.N, N_samples))
    y = np.zeros(shape=(N_samples, 1))
    for j in range(N_samples):
        # generate a random ris setting
        sys.ris.set_random_binary_phase_shifts()
        x = sys.ris.vector_x
        X[:, j] = x.flatten()
        y[j] = sys.cal_snr() - sys.c_true

    sens = sensing.Sensing(B=B, N=sys.ris.N)
    M_est, w_est, _ = sens.solve(X=X, y=y, convergence_plot=False) # Stage 1: sensing
    M_est_proj = sens.project_to_psd_lowrank(M_est, r=2) # projection to low rank
    sys.ris.vector_x = opt.solve_our_optimization(M_est_proj, w_est) # Stage 2: optimization
    sys.ris.theta = np.arccos(sys.ris.vector_x)
    born = 10 * np.log10(sys.cal_snr())
    
    all_born_3000.append(born)
# Out:
# ---------------------------
# Computing LOOP 0
# ---------------------------
# Computing LOOP 1
# ---------------------------
# Computing LOOP 2
# ---------------------------
# Computing LOOP 3
# ---------------------------
# Computing LOOP 4
# ---------------------------
# Computing LOOP 5
# ---------------------------
# Computing LOOP 6
# ---------------------------
# Computing LOOP 7
# ---------------------------
# Computing LOOP 8
# ---------------------------
# Computing LOOP 9
# ---------------------------
# Computing LOOP 10
# ---------------------------
# Computing LOOP 11
# ---------------------------
# Computing LOOP 12
# ---------------------------
# Computing LOOP 13
# ---------------------------
# Computing LOOP 14
# ---------------------------
# Computing LOOP 15
# ---------------------------
# Computing LOOP 16
# ---------------------------
# Computing LOOP 17
# ---------------------------
# Computing LOOP 18
# ---------------------------
# Computing LOOP 19
# ---------------------------
# Computing LOOP 20
# ---------------------------
# Computing LOOP 21
# ---------------------------
# Computing LOOP 22
# ---------------------------
# Computing LOOP 23
# ---------------------------
# Computing LOOP 24
# ---------------------------
# Computing LOOP 25
# ---------------------------
# Computing LOOP 26
# ---------------------------
# Computing LOOP 27
# ---------------------------
# Computing LOOP 28
# ---------------------------
# Computing LOOP 29
# ---------------------------
# Computing LOOP 30
# ---------------------------
# Computing LOOP 31
# ---------------------------
# Computing LOOP 32
# ---------------------------
# Computing LOOP 33
# ---------------------------
# Computing LOOP 34
# ---------------------------
# Computing LOOP 35
# ---------------------------
# Computing LOOP 36
# ---------------------------
# Computing LOOP 37
# ---------------------------
# Computing LOOP 38
# ---------------------------
# Computing LOOP 39
# ---------------------------
# Computing LOOP 40
# ---------------------------
# Computing LOOP 41
# ---------------------------
# Computing LOOP 42
# ---------------------------
# Computing LOOP 43
# ---------------------------
# Computing LOOP 44
# ---------------------------
# Computing LOOP 45
# ---------------------------
# Computing LOOP 46
# ---------------------------
# Computing LOOP 47
# ---------------------------
# Computing LOOP 48
# ---------------------------
# Computing LOOP 49
# ---------------------------
# Computing LOOP 50
# ---------------------------
# Computing LOOP 51
# ---------------------------
# Computing LOOP 52
# ---------------------------
# Computing LOOP 53
# ---------------------------
# Computing LOOP 54
# ---------------------------
# Computing LOOP 55
# ---------------------------
# Computing LOOP 56
# ---------------------------
# Computing LOOP 57
# ---------------------------
# Computing LOOP 58
# ---------------------------
# Computing LOOP 59
# ---------------------------
# Computing LOOP 60
# ---------------------------
# Computing LOOP 61
# ---------------------------
# Computing LOOP 62
# ---------------------------
# Computing LOOP 63
# ---------------------------
# Computing LOOP 64
# ---------------------------
# Computing LOOP 65
# ---------------------------
# Computing LOOP 66
# ---------------------------
# Computing LOOP 67
# ---------------------------
# Computing LOOP 68
# ---------------------------
# Computing LOOP 69
# ---------------------------
# Computing LOOP 70
# ---------------------------
# Computing LOOP 71
# ---------------------------
# Computing LOOP 72
# ---------------------------
# Computing LOOP 73
# ---------------------------
# Computing LOOP 74
# ---------------------------
# Computing LOOP 75
# ---------------------------
# Computing LOOP 76
# ---------------------------
# Computing LOOP 77
# ---------------------------
# Computing LOOP 78
# ---------------------------
# Computing LOOP 79
# ---------------------------
# Computing LOOP 80
# ---------------------------
# Computing LOOP 81
# ---------------------------
# Computing LOOP 82
# ---------------------------
# Computing LOOP 83
# ---------------------------
# Computing LOOP 84
# ---------------------------
# Computing LOOP 85
# ---------------------------
# Computing LOOP 86
# ---------------------------
# Computing LOOP 87
# ---------------------------
# Computing LOOP 88
# ---------------------------
# Computing LOOP 89
# ---------------------------
# Computing LOOP 90
# ---------------------------
# Computing LOOP 91
# ---------------------------
# Computing LOOP 92
# ---------------------------
# Computing LOOP 93
# ---------------------------
# Computing LOOP 94
# ---------------------------
# Computing LOOP 95
# ---------------------------
# Computing LOOP 96
# ---------------------------
# Computing LOOP 97
# ---------------------------
# Computing LOOP 98
# ---------------------------
# Computing LOOP 99
# ---------------------------
# Computing LOOP 100
# ---------------------------
# Computing LOOP 101
# ---------------------------
# Computing LOOP 102
# ---------------------------
# Computing LOOP 103
# ---------------------------
# Computing LOOP 104
# ---------------------------
# Computing LOOP 105
# ---------------------------
# Computing LOOP 106
# ---------------------------
# Computing LOOP 107
# ---------------------------
# Computing LOOP 108
# ---------------------------
# Computing LOOP 109
# ---------------------------
# Computing LOOP 110
# ---------------------------
# Computing LOOP 111
# ---------------------------
# Computing LOOP 112
# ---------------------------
# Computing LOOP 113
# ---------------------------
# Computing LOOP 114
# ---------------------------
# Computing LOOP 115
# ---------------------------
# Computing LOOP 116
# ---------------------------
# Computing LOOP 117
# ---------------------------
# Computing LOOP 118
# ---------------------------
# Computing LOOP 119
# ---------------------------
# Computing LOOP 120
# ---------------------------
# Computing LOOP 121
# ---------------------------
# Computing LOOP 122
# ---------------------------
# Computing LOOP 123
# ---------------------------
# Computing LOOP 124
# ---------------------------
# Computing LOOP 125
# ---------------------------
# Computing LOOP 126
# ---------------------------
# Computing LOOP 127
# ---------------------------
# Computing LOOP 128
# ---------------------------
# Computing LOOP 129
# ---------------------------
# Computing LOOP 130
# ---------------------------
# Computing LOOP 131
# ---------------------------
# Computing LOOP 132
# ---------------------------
# Computing LOOP 133
# ---------------------------
# Computing LOOP 134
# ---------------------------
# Computing LOOP 135
# ---------------------------
# Computing LOOP 136
# ---------------------------
# Computing LOOP 137
# ---------------------------
# Computing LOOP 138
# ---------------------------
# Computing LOOP 139
# ---------------------------
# Computing LOOP 140
# ---------------------------
# Computing LOOP 141
# ---------------------------
# Computing LOOP 142
# ---------------------------
# Computing LOOP 143
# ---------------------------
# Computing LOOP 144
# ---------------------------
# Computing LOOP 145
# ---------------------------
# Computing LOOP 146
# ---------------------------
# Computing LOOP 147
# ---------------------------
# Computing LOOP 148
# ---------------------------
# Computing LOOP 149
# ---------------------------
# Computing LOOP 150
# ---------------------------
# Computing LOOP 151
# ---------------------------
# Computing LOOP 152
# ---------------------------
# Computing LOOP 153
# ---------------------------
# Computing LOOP 154
# ---------------------------
# Computing LOOP 155
# ---------------------------
# Computing LOOP 156
# ---------------------------
# Computing LOOP 157
# ---------------------------
# Computing LOOP 158
# ---------------------------
# Computing LOOP 159
# ---------------------------
# Computing LOOP 160
# ---------------------------
# Computing LOOP 161
# ---------------------------
# Computing LOOP 162
# ---------------------------
# Computing LOOP 163
# ---------------------------
# Computing LOOP 164
# ---------------------------
# Computing LOOP 165
# ---------------------------
# Computing LOOP 166
# ---------------------------
# Computing LOOP 167
# ---------------------------
# Computing LOOP 168
# ---------------------------
# Computing LOOP 169
# ---------------------------
# Computing LOOP 170
# ---------------------------
# Computing LOOP 171
# ---------------------------
# Computing LOOP 172
# ---------------------------
# Computing LOOP 173
# ---------------------------
# Computing LOOP 174
# ---------------------------
# Computing LOOP 175
# ---------------------------
# Computing LOOP 176
# ---------------------------
# Computing LOOP 177
# ---------------------------
# Computing LOOP 178
# ---------------------------
# Computing LOOP 179
# ---------------------------
# Computing LOOP 180
# ---------------------------
# Computing LOOP 181
# ---------------------------
# Computing LOOP 182
# ---------------------------
# Computing LOOP 183
# ---------------------------
# Computing LOOP 184
# ---------------------------
# Computing LOOP 185
# ---------------------------
# Computing LOOP 186
# ---------------------------
# Computing LOOP 187
# ---------------------------
# Computing LOOP 188
# ---------------------------
# Computing LOOP 189
# ---------------------------
# Computing LOOP 190
# ---------------------------
# Computing LOOP 191
# ---------------------------
# Computing LOOP 192
# ---------------------------
# Computing LOOP 193
# ---------------------------
# Computing LOOP 194
# ---------------------------
# Computing LOOP 195
# ---------------------------
# Computing LOOP 196
# ---------------------------
# Computing LOOP 197
# ---------------------------
# Computing LOOP 198
# ---------------------------
# Computing LOOP 199
# ---------------------------
# Computing LOOP 200
# ---------------------------
# Computing LOOP 201
# ---------------------------
# Computing LOOP 202
# ---------------------------
# Computing LOOP 203
# ---------------------------
# Computing LOOP 204
# ---------------------------
# Computing LOOP 205
# ---------------------------
# Computing LOOP 206
# ---------------------------
# Computing LOOP 207
# ---------------------------
# Computing LOOP 208
# ---------------------------
# Computing LOOP 209
# ---------------------------
# Computing LOOP 210
# ---------------------------
# Computing LOOP 211
# ---------------------------
# Computing LOOP 212
# ---------------------------
# Computing LOOP 213
# ---------------------------
# Computing LOOP 214
# ---------------------------
# Computing LOOP 215
# ---------------------------
# Computing LOOP 216
# ---------------------------
# Computing LOOP 217
# ---------------------------
# Computing LOOP 218
# ---------------------------
# Computing LOOP 219
# ---------------------------
# Computing LOOP 220
# ---------------------------
# Computing LOOP 221
# ---------------------------
# Computing LOOP 222
# ---------------------------
# Computing LOOP 223
# ---------------------------
# Computing LOOP 224
# ---------------------------
# Computing LOOP 225
# ---------------------------
# Computing LOOP 226
# ---------------------------
# Computing LOOP 227
# ---------------------------
# Computing LOOP 228
# ---------------------------
# Computing LOOP 229
# ---------------------------
# Computing LOOP 230
# ---------------------------
# Computing LOOP 231
# ---------------------------
# Computing LOOP 232
# ---------------------------
# Computing LOOP 233
# ---------------------------
# Computing LOOP 234
# ---------------------------
# Computing LOOP 235
# ---------------------------
# Computing LOOP 236
# ---------------------------
# Computing LOOP 237
# ---------------------------
# Computing LOOP 238
# ---------------------------
# Computing LOOP 239
# ---------------------------
# Computing LOOP 240
# ---------------------------
# Computing LOOP 241
# ---------------------------
# Computing LOOP 242
# ---------------------------
# Computing LOOP 243
# ---------------------------
# Computing LOOP 244
# ---------------------------
# Computing LOOP 245
# ---------------------------
# Computing LOOP 246
# ---------------------------
# Computing LOOP 247
# ---------------------------
# Computing LOOP 248
# ---------------------------
# Computing LOOP 249
# ---------------------------
# Computing LOOP 250
# ---------------------------
# Computing LOOP 251
# ---------------------------
# Computing LOOP 252
# ---------------------------
# Computing LOOP 253
# ---------------------------
# Computing LOOP 254
# ---------------------------
# Computing LOOP 255
# ---------------------------
# Computing LOOP 256
# ---------------------------
# Computing LOOP 257
# ---------------------------
# Computing LOOP 258
# ---------------------------
# Computing LOOP 259
# ---------------------------
# Computing LOOP 260
# ---------------------------
# Computing LOOP 261
# ---------------------------
# Computing LOOP 262
# ---------------------------
# Computing LOOP 263
# ---------------------------
# Computing LOOP 264
# ---------------------------
# Computing LOOP 265
# ---------------------------
# Computing LOOP 266
# ---------------------------
# Computing LOOP 267
# ---------------------------
# Computing LOOP 268
# ---------------------------
# Computing LOOP 269
# ---------------------------
# Computing LOOP 270
# ---------------------------
# Computing LOOP 271
# ---------------------------
# Computing LOOP 272
# ---------------------------
# Computing LOOP 273
# ---------------------------
# Computing LOOP 274
# ---------------------------
# Computing LOOP 275
# ---------------------------
# Computing LOOP 276
# ---------------------------
# Computing LOOP 277
# ---------------------------
# Computing LOOP 278
# ---------------------------
# Computing LOOP 279
# ---------------------------
# Computing LOOP 280
# ---------------------------
# Computing LOOP 281
# ---------------------------
# Computing LOOP 282
# ---------------------------
# Computing LOOP 283
# ---------------------------
# Computing LOOP 284
# ---------------------------
# Computing LOOP 285
# ---------------------------
# Computing LOOP 286
# ---------------------------
# Computing LOOP 287
# ---------------------------
# Computing LOOP 288
# ---------------------------
# Computing LOOP 289
# ---------------------------
# Computing LOOP 290
# ---------------------------
# Computing LOOP 291
# ---------------------------
# Computing LOOP 292
# ---------------------------
# Computing LOOP 293
# ---------------------------
# Computing LOOP 294
# ---------------------------
# Computing LOOP 295
# ---------------------------
# Computing LOOP 296
# ---------------------------
# Computing LOOP 297
# ---------------------------
# Computing LOOP 298
# ---------------------------
# Computing LOOP 299
# ---------------------------
# Computing LOOP 300
# ---------------------------
# Computing LOOP 301
# ---------------------------
# Computing LOOP 302
# ---------------------------
# Computing LOOP 303
# ---------------------------
# Computing LOOP 304
# ---------------------------
# Computing LOOP 305
# ---------------------------
# Computing LOOP 306
# ---------------------------
# Computing LOOP 307
# ---------------------------
# Computing LOOP 308
# ---------------------------
# Computing LOOP 309
# ---------------------------
# Computing LOOP 310
# ---------------------------
# Computing LOOP 311
# ---------------------------
# Computing LOOP 312
# ---------------------------
# Computing LOOP 313
# ---------------------------
# Computing LOOP 314
# ---------------------------
# Computing LOOP 315
# ---------------------------
# Computing LOOP 316
# ---------------------------
# Computing LOOP 317
# ---------------------------
# Computing LOOP 318
# ---------------------------
# Computing LOOP 319
# ---------------------------
# Computing LOOP 320
# ---------------------------
# Computing LOOP 321
# ---------------------------
# Computing LOOP 322
# ---------------------------
# Computing LOOP 323
# ---------------------------
# Computing LOOP 324
# ---------------------------
# Computing LOOP 325
# ---------------------------
# Computing LOOP 326
# ---------------------------
# Computing LOOP 327
# ---------------------------
# Computing LOOP 328
# ---------------------------
# Computing LOOP 329
# ---------------------------
# Computing LOOP 330
# ---------------------------
# Computing LOOP 331
# ---------------------------
# Computing LOOP 332
# ---------------------------
# Computing LOOP 333
# ---------------------------
# Computing LOOP 334
# ---------------------------
# Computing LOOP 335
# ---------------------------
# Computing LOOP 336
# ---------------------------
# Computing LOOP 337
# ---------------------------
# Computing LOOP 338
# ---------------------------
# Computing LOOP 339
# ---------------------------
# Computing LOOP 340
# ---------------------------
# Computing LOOP 341
# ---------------------------
# Computing LOOP 342
# ---------------------------
# Computing LOOP 343
# ---------------------------
# Computing LOOP 344
# ---------------------------
# Computing LOOP 345
# ---------------------------
# Computing LOOP 346
# ---------------------------
# Computing LOOP 347
# ---------------------------
# Computing LOOP 348
# ---------------------------
# Computing LOOP 349
# ---------------------------
# Computing LOOP 350
# ---------------------------
# Computing LOOP 351
# ---------------------------
# Computing LOOP 352
# ---------------------------
# Computing LOOP 353
# ---------------------------
# Computing LOOP 354
# ---------------------------
# Computing LOOP 355
# ---------------------------
# Computing LOOP 356
# ---------------------------
# Computing LOOP 357
# ---------------------------
# Computing LOOP 358
# ---------------------------
# Computing LOOP 359
# ---------------------------
# Computing LOOP 360
# ---------------------------
# Computing LOOP 361
# ---------------------------
# Computing LOOP 362
# ---------------------------
# Computing LOOP 363
# ---------------------------
# Computing LOOP 364
# ---------------------------
# Computing LOOP 365
# ---------------------------
# Computing LOOP 366
# ---------------------------
# Computing LOOP 367
# ---------------------------
# Computing LOOP 368
# ---------------------------
# Computing LOOP 369
# ---------------------------
# Computing LOOP 370
# ---------------------------
# Computing LOOP 371
# ---------------------------
# Computing LOOP 372
# ---------------------------
# Computing LOOP 373
# ---------------------------
# Computing LOOP 374
# ---------------------------
# Computing LOOP 375
# ---------------------------
# Computing LOOP 376
# ---------------------------
# Computing LOOP 377
# ---------------------------
# Computing LOOP 378
# ---------------------------
# Computing LOOP 379
# ---------------------------
# Computing LOOP 380
# ---------------------------
# Computing LOOP 381
# ---------------------------
# Computing LOOP 382
# ---------------------------
# Computing LOOP 383
# ---------------------------
# Computing LOOP 384
# ---------------------------
# Computing LOOP 385
# ---------------------------
# Computing LOOP 386
# ---------------------------
# Computing LOOP 387
# ---------------------------
# Computing LOOP 388
# ---------------------------
# Computing LOOP 389
# ---------------------------
# Computing LOOP 390
# ---------------------------
# Computing LOOP 391
# ---------------------------
# Computing LOOP 392
# ---------------------------
# Computing LOOP 393
# ---------------------------
# Computing LOOP 394
# ---------------------------
# Computing LOOP 395
# ---------------------------
# Computing LOOP 396
# ---------------------------
# Computing LOOP 397
# ---------------------------
# Computing LOOP 398
# ---------------------------
# Computing LOOP 399
# ---------------------------
# Computing LOOP 400
# ---------------------------
# Computing LOOP 401
# ---------------------------
# Computing LOOP 402
# ---------------------------
# Computing LOOP 403
# ---------------------------
# Computing LOOP 404
# ---------------------------
# Computing LOOP 405
# ---------------------------
# Computing LOOP 406
# ---------------------------
# Computing LOOP 407
# ---------------------------
# Computing LOOP 408
# ---------------------------
# Computing LOOP 409
# ---------------------------
# Computing LOOP 410
# ---------------------------
# Computing LOOP 411
# ---------------------------
# Computing LOOP 412
# ---------------------------
# Computing LOOP 413
# ---------------------------
# Computing LOOP 414
# ---------------------------
# Computing LOOP 415
# ---------------------------
# Computing LOOP 416
# ---------------------------
# Computing LOOP 417
# ---------------------------
# Computing LOOP 418
# ---------------------------
# Computing LOOP 419
# ---------------------------
# Computing LOOP 420
# ---------------------------
# Computing LOOP 421
# ---------------------------
# Computing LOOP 422
# ---------------------------
# Computing LOOP 423
# ---------------------------
# Computing LOOP 424
# ---------------------------
# Computing LOOP 425
# ---------------------------
# Computing LOOP 426
# ---------------------------
# Computing LOOP 427
# ---------------------------
# Computing LOOP 428
# ---------------------------
# Computing LOOP 429
# ---------------------------
# Computing LOOP 430
# ---------------------------
# Computing LOOP 431
# ---------------------------
# Computing LOOP 432
# ---------------------------
# Computing LOOP 433
# ---------------------------
# Computing LOOP 434
# ---------------------------
# Computing LOOP 435
# ---------------------------
# Computing LOOP 436
# ---------------------------
# Computing LOOP 437
# ---------------------------
# Computing LOOP 438
# ---------------------------
# Computing LOOP 439
# ---------------------------
# Computing LOOP 440
# ---------------------------
# Computing LOOP 441
# ---------------------------
# Computing LOOP 442
# ---------------------------
# Computing LOOP 443
# ---------------------------
# Computing LOOP 444
# ---------------------------
# Computing LOOP 445
# ---------------------------
# Computing LOOP 446
# ---------------------------
# Computing LOOP 447
# ---------------------------
# Computing LOOP 448
# ---------------------------
# Computing LOOP 449
# ---------------------------
# Computing LOOP 450
# ---------------------------
# Computing LOOP 451
# ---------------------------
# Computing LOOP 452
# ---------------------------
# Computing LOOP 453
# ---------------------------
# Computing LOOP 454
# ---------------------------
# Computing LOOP 455
# ---------------------------
# Computing LOOP 456
# ---------------------------
# Computing LOOP 457
# ---------------------------
# Computing LOOP 458
# ---------------------------
# Computing LOOP 459
# ---------------------------
# Computing LOOP 460
# ---------------------------
# Computing LOOP 461
# ---------------------------
# Computing LOOP 462
# ---------------------------
# Computing LOOP 463
# ---------------------------
# Computing LOOP 464
# ---------------------------
# Computing LOOP 465
# ---------------------------
# Computing LOOP 466
# ---------------------------
# Computing LOOP 467
# ---------------------------
# Computing LOOP 468
# ---------------------------
# Computing LOOP 469
# ---------------------------
# Computing LOOP 470
# ---------------------------
# Computing LOOP 471
# ---------------------------
# Computing LOOP 472
# ---------------------------
# Computing LOOP 473
# ---------------------------
# Computing LOOP 474
# ---------------------------
# Computing LOOP 475
# ---------------------------
# Computing LOOP 476
# ---------------------------
# Computing LOOP 477
# ---------------------------
# Computing LOOP 478
# ---------------------------
# Computing LOOP 479
# ---------------------------
# Computing LOOP 480
# ---------------------------
# Computing LOOP 481
# ---------------------------
# Computing LOOP 482
# ---------------------------
# Computing LOOP 483
# ---------------------------
# Computing LOOP 484
# ---------------------------
# Computing LOOP 485
# ---------------------------
# Computing LOOP 486
# ---------------------------
# Computing LOOP 487
# ---------------------------
# Computing LOOP 488
# ---------------------------
# Computing LOOP 489
# ---------------------------
# Computing LOOP 490
# ---------------------------
# Computing LOOP 491
# ---------------------------
# Computing LOOP 492
# ---------------------------
# Computing LOOP 493
# ---------------------------
# Computing LOOP 494
# ---------------------------
# Computing LOOP 495
# ---------------------------
# Computing LOOP 496
# ---------------------------
# Computing LOOP 497
# ---------------------------
# Computing LOOP 498
# ---------------------------
# Computing LOOP 499
# ---------------------------
# Computing LOOP 500
# ---------------------------
# Computing LOOP 501
# ---------------------------
# Computing LOOP 502
# ---------------------------
# Computing LOOP 503
# ---------------------------
# Computing LOOP 504
# ---------------------------
# Computing LOOP 505
# ---------------------------
# Computing LOOP 506
# ---------------------------
# Computing LOOP 507
# ---------------------------
# Computing LOOP 508
# ---------------------------
# Computing LOOP 509
# ---------------------------
# Computing LOOP 510
# ---------------------------
# Computing LOOP 511
# ---------------------------
# Computing LOOP 512
# ---------------------------
# Computing LOOP 513
# ---------------------------
# Computing LOOP 514
# ---------------------------
# Computing LOOP 515
# ---------------------------
# Computing LOOP 516
# ---------------------------
# Computing LOOP 517
# ---------------------------
# Computing LOOP 518
# ---------------------------
# Computing LOOP 519
# ---------------------------
# Computing LOOP 520
# ---------------------------
# Computing LOOP 521
# ---------------------------
# Computing LOOP 522
# ---------------------------
# Computing LOOP 523
# ---------------------------
# Computing LOOP 524
# ---------------------------
# Computing LOOP 525
# ---------------------------
# Computing LOOP 526
# ---------------------------
# Computing LOOP 527
# ---------------------------
# Computing LOOP 528
# ---------------------------
# Computing LOOP 529
# ---------------------------
# Computing LOOP 530
# ---------------------------
# Computing LOOP 531
# ---------------------------
# Computing LOOP 532
# ---------------------------
# Computing LOOP 533
# ---------------------------
# Computing LOOP 534
# ---------------------------
# Computing LOOP 535
# ---------------------------
# Computing LOOP 536
# ---------------------------
# Computing LOOP 537
# ---------------------------
# Computing LOOP 538
# ---------------------------
# Computing LOOP 539
# ---------------------------
# Computing LOOP 540
# ---------------------------
# Computing LOOP 541
# ---------------------------
# Computing LOOP 542
# ---------------------------
# Computing LOOP 543
# ---------------------------
# Computing LOOP 544
# ---------------------------
# Computing LOOP 545
# ---------------------------
# Computing LOOP 546
# ---------------------------
# Computing LOOP 547
# ---------------------------
# Computing LOOP 548
# ---------------------------
# Computing LOOP 549
# ---------------------------
# Computing LOOP 550
# ---------------------------
# Computing LOOP 551
# ---------------------------
# Computing LOOP 552
# ---------------------------
# Computing LOOP 553
# ---------------------------
# Computing LOOP 554
# ---------------------------
# Computing LOOP 555
# ---------------------------
# Computing LOOP 556
# ---------------------------
# Computing LOOP 557
# ---------------------------
# Computing LOOP 558
# ---------------------------
# Computing LOOP 559
# ---------------------------
# Computing LOOP 560
# ---------------------------
# Computing LOOP 561
# ---------------------------
# Computing LOOP 562
# ---------------------------
# Computing LOOP 563
# ---------------------------
# Computing LOOP 564
# ---------------------------
# Computing LOOP 565
# ---------------------------
# Computing LOOP 566
# ---------------------------
# Computing LOOP 567
# ---------------------------
# Computing LOOP 568
# ---------------------------
# Computing LOOP 569
# ---------------------------
# Computing LOOP 570
# ---------------------------
# Computing LOOP 571
# ---------------------------
# Computing LOOP 572
# ---------------------------
# Computing LOOP 573
# ---------------------------
# Computing LOOP 574
# ---------------------------
# Computing LOOP 575
# ---------------------------
# Computing LOOP 576
# ---------------------------
# Computing LOOP 577
# ---------------------------
# Computing LOOP 578
# ---------------------------
# Computing LOOP 579
# ---------------------------
# Computing LOOP 580
# ---------------------------
# Computing LOOP 581
# ---------------------------
# Computing LOOP 582
# ---------------------------
# Computing LOOP 583
# ---------------------------
# Computing LOOP 584
# ---------------------------
# Computing LOOP 585
# ---------------------------
# Computing LOOP 586
# ---------------------------
# Computing LOOP 587
# ---------------------------
# Computing LOOP 588
# ---------------------------
# Computing LOOP 589
# ---------------------------
# Computing LOOP 590
# ---------------------------
# Computing LOOP 591
# ---------------------------
# Computing LOOP 592
# ---------------------------
# Computing LOOP 593
# ---------------------------
# Computing LOOP 594
# ---------------------------
# Computing LOOP 595
# ---------------------------
# Computing LOOP 596
# ---------------------------
# Computing LOOP 597
# ---------------------------
# Computing LOOP 598
# ---------------------------
# Computing LOOP 599
# ---------------------------
# Computing LOOP 600
# ---------------------------
# Computing LOOP 601
# ---------------------------
# Computing LOOP 602
# ---------------------------
# Computing LOOP 603
# ---------------------------
# Computing LOOP 604
# ---------------------------
# Computing LOOP 605
# ---------------------------
# Computing LOOP 606
# ---------------------------
# Computing LOOP 607
# ---------------------------
# Computing LOOP 608
# ---------------------------
# Computing LOOP 609
# ---------------------------
# Computing LOOP 610
# ---------------------------
# Computing LOOP 611
# ---------------------------
# Computing LOOP 612
# ---------------------------
# Computing LOOP 613
# ---------------------------
# Computing LOOP 614
# ---------------------------
# Computing LOOP 615
# ---------------------------
# Computing LOOP 616
# ---------------------------
# Computing LOOP 617
# ---------------------------
# Computing LOOP 618
# ---------------------------
# Computing LOOP 619
# ---------------------------
# Computing LOOP 620
# ---------------------------
# Computing LOOP 621
# ---------------------------
# Computing LOOP 622
# ---------------------------
# Computing LOOP 623
# ---------------------------
# Computing LOOP 624
# ---------------------------
# Computing LOOP 625
# ---------------------------
# Computing LOOP 626
# ---------------------------
# Computing LOOP 627
# ---------------------------
# Computing LOOP 628
# ---------------------------
# Computing LOOP 629
# ---------------------------
# Computing LOOP 630
# ---------------------------
# Computing LOOP 631
# ---------------------------
# Computing LOOP 632
# ---------------------------
# Computing LOOP 633
# ---------------------------
# Computing LOOP 634
# ---------------------------
# Computing LOOP 635
# ---------------------------
# Computing LOOP 636
# ---------------------------
# Computing LOOP 637
# ---------------------------
# Computing LOOP 638
# ---------------------------
# Computing LOOP 639
# ---------------------------
# Computing LOOP 640
# ---------------------------
# Computing LOOP 641
# ---------------------------
# Computing LOOP 642
# ---------------------------
# Computing LOOP 643
# ---------------------------
# Computing LOOP 644
# ---------------------------
# Computing LOOP 645
# ---------------------------
# Computing LOOP 646
# ---------------------------
# Computing LOOP 647
# ---------------------------
# Computing LOOP 648
# ---------------------------
# Computing LOOP 649
# ---------------------------
# Computing LOOP 650
# ---------------------------
# Computing LOOP 651
# ---------------------------
# Computing LOOP 652
# ---------------------------
# Computing LOOP 653
# ---------------------------
# Computing LOOP 654
# ---------------------------
# Computing LOOP 655
# ---------------------------
# Computing LOOP 656
# ---------------------------
# Computing LOOP 657
# ---------------------------
# Computing LOOP 658
# ---------------------------
# Computing LOOP 659
# ---------------------------
# Computing LOOP 660
# ---------------------------
# Computing LOOP 661
# ---------------------------
# Computing LOOP 662
# ---------------------------
# Computing LOOP 663
# ---------------------------
# Computing LOOP 664
# ---------------------------
# Computing LOOP 665
# ---------------------------
# Computing LOOP 666
# ---------------------------
# Computing LOOP 667
# ---------------------------
# Computing LOOP 668
# ---------------------------
# Computing LOOP 669
# ---------------------------
# Computing LOOP 670
# ---------------------------
# Computing LOOP 671
# ---------------------------
# Computing LOOP 672
# ---------------------------
# Computing LOOP 673
# ---------------------------
# Computing LOOP 674
# ---------------------------
# Computing LOOP 675
# ---------------------------
# Computing LOOP 676
# ---------------------------
# Computing LOOP 677
# ---------------------------
# Computing LOOP 678
# ---------------------------
# Computing LOOP 679
# ---------------------------
# Computing LOOP 680
# ---------------------------
# Computing LOOP 681
# ---------------------------
# Computing LOOP 682
# ---------------------------
# Computing LOOP 683
# ---------------------------
# Computing LOOP 684
# ---------------------------
# Computing LOOP 685
# ---------------------------
# Computing LOOP 686
# ---------------------------
# Computing LOOP 687
# ---------------------------
# Computing LOOP 688
# ---------------------------
# Computing LOOP 689
# ---------------------------
# Computing LOOP 690
# ---------------------------
# Computing LOOP 691
# ---------------------------
# Computing LOOP 692
# ---------------------------
# Computing LOOP 693
# ---------------------------
# Computing LOOP 694
# ---------------------------
# Computing LOOP 695
# ---------------------------
# Computing LOOP 696
# ---------------------------
# Computing LOOP 697
# ---------------------------
# Computing LOOP 698
# ---------------------------
# Computing LOOP 699
# ---------------------------
# Computing LOOP 700
# ---------------------------
# Computing LOOP 701
# ---------------------------
# Computing LOOP 702
# ---------------------------
# Computing LOOP 703
# ---------------------------
# Computing LOOP 704
# ---------------------------
# Computing LOOP 705
# ---------------------------
# Computing LOOP 706
# ---------------------------
# Computing LOOP 707
# ---------------------------
# Computing LOOP 708
# ---------------------------
# Computing LOOP 709
# ---------------------------
# Computing LOOP 710
# ---------------------------
# Computing LOOP 711
# ---------------------------
# Computing LOOP 712
# ---------------------------
# Computing LOOP 713
# ---------------------------
# Computing LOOP 714
# ---------------------------
# Computing LOOP 715
# ---------------------------
# Computing LOOP 716
# ---------------------------
# Computing LOOP 717
# ---------------------------
# Computing LOOP 718
# ---------------------------
# Computing LOOP 719
# ---------------------------
# Computing LOOP 720
# ---------------------------
# Computing LOOP 721
# ---------------------------
# Computing LOOP 722
# ---------------------------
# Computing LOOP 723
# ---------------------------
# Computing LOOP 724
# ---------------------------
# Computing LOOP 725
# ---------------------------
# Computing LOOP 726
# ---------------------------
# Computing LOOP 727
# ---------------------------
# Computing LOOP 728
# ---------------------------
# Computing LOOP 729
# ---------------------------
# Computing LOOP 730
# ---------------------------
# Computing LOOP 731
# ---------------------------
# Computing LOOP 732
# ---------------------------
# Computing LOOP 733
# ---------------------------
# Computing LOOP 734
# ---------------------------
# Computing LOOP 735
# ---------------------------
# Computing LOOP 736
# ---------------------------
# Computing LOOP 737
# ---------------------------
# Computing LOOP 738
# ---------------------------
# Computing LOOP 739
# ---------------------------
# Computing LOOP 740
# ---------------------------
# Computing LOOP 741
# ---------------------------
# Computing LOOP 742
# ---------------------------
# Computing LOOP 743
# ---------------------------
# Computing LOOP 744
# ---------------------------
# Computing LOOP 745
# ---------------------------
# Computing LOOP 746
# ---------------------------
# Computing LOOP 747
# ---------------------------
# Computing LOOP 748
# ---------------------------
# Computing LOOP 749
# ---------------------------
# Computing LOOP 750
# ---------------------------
# Computing LOOP 751
# ---------------------------
# Computing LOOP 752
# ---------------------------
# Computing LOOP 753
# ---------------------------
# Computing LOOP 754
# ---------------------------
# Computing LOOP 755
# ---------------------------
# Computing LOOP 756
# ---------------------------
# Computing LOOP 757
# ---------------------------
# Computing LOOP 758
# ---------------------------
# Computing LOOP 759
# ---------------------------
# Computing LOOP 760
# ---------------------------
# Computing LOOP 761
# ---------------------------
# Computing LOOP 762
# ---------------------------
# Computing LOOP 763
# ---------------------------
# Computing LOOP 764
# ---------------------------
# Computing LOOP 765
# ---------------------------
# Computing LOOP 766
# ---------------------------
# Computing LOOP 767
# ---------------------------
# Computing LOOP 768
# ---------------------------
# Computing LOOP 769
# ---------------------------
# Computing LOOP 770
# ---------------------------
# Computing LOOP 771
# ---------------------------
# Computing LOOP 772
# ---------------------------
# Computing LOOP 773
# ---------------------------
# Computing LOOP 774
# ---------------------------
# Computing LOOP 775
# ---------------------------
# Computing LOOP 776
# ---------------------------
# Computing LOOP 777
# ---------------------------
# Computing LOOP 778
# ---------------------------
# Computing LOOP 779
# ---------------------------
# Computing LOOP 780
# ---------------------------
# Computing LOOP 781
# ---------------------------
# Computing LOOP 782
# ---------------------------
# Computing LOOP 783
# ---------------------------
# Computing LOOP 784
# ---------------------------
# Computing LOOP 785
# ---------------------------
# Computing LOOP 786
# ---------------------------
# Computing LOOP 787
# ---------------------------
# Computing LOOP 788
# ---------------------------
# Computing LOOP 789
# ---------------------------
# Computing LOOP 790
# ---------------------------
# Computing LOOP 791
# ---------------------------
# Computing LOOP 792
# ---------------------------
# Computing LOOP 793
# ---------------------------
# Computing LOOP 794
# ---------------------------
# Computing LOOP 795
# ---------------------------
# Computing LOOP 796
# ---------------------------
# Computing LOOP 797
# ---------------------------
# Computing LOOP 798
# ---------------------------
# Computing LOOP 799
# ---------------------------
# Computing LOOP 800
# ---------------------------
# Computing LOOP 801
# ---------------------------
# Computing LOOP 802
# ---------------------------
# Computing LOOP 803
# ---------------------------
# Computing LOOP 804
# ---------------------------
# Computing LOOP 805
# ---------------------------
# Computing LOOP 806
# ---------------------------
# Computing LOOP 807
# ---------------------------
# Computing LOOP 808
# ---------------------------
# Computing LOOP 809
# ---------------------------
# Computing LOOP 810
# ---------------------------
# Computing LOOP 811
# ---------------------------
# Computing LOOP 812
# ---------------------------
# Computing LOOP 813
# ---------------------------
# Computing LOOP 814
# ---------------------------
# Computing LOOP 815
# ---------------------------
# Computing LOOP 816
# ---------------------------
# Computing LOOP 817
# ---------------------------
# Computing LOOP 818
# ---------------------------
# Computing LOOP 819
# ---------------------------
# Computing LOOP 820
# ---------------------------
# Computing LOOP 821
# ---------------------------
# Computing LOOP 822
# ---------------------------
# Computing LOOP 823
# ---------------------------
# Computing LOOP 824
# ---------------------------
# Computing LOOP 825
# ---------------------------
# Computing LOOP 826
# ---------------------------
# Computing LOOP 827
# ---------------------------
# Computing LOOP 828
# ---------------------------
# Computing LOOP 829
# ---------------------------
# Computing LOOP 830
# ---------------------------
# Computing LOOP 831
# ---------------------------
# Computing LOOP 832
# ---------------------------
# Computing LOOP 833
# ---------------------------
# Computing LOOP 834
# ---------------------------
# Computing LOOP 835
# ---------------------------
# Computing LOOP 836
# ---------------------------
# Computing LOOP 837
# ---------------------------
# Computing LOOP 838
# ---------------------------
# Computing LOOP 839
# ---------------------------
# Computing LOOP 840
# ---------------------------
# Computing LOOP 841
# ---------------------------
# Computing LOOP 842
# ---------------------------
# Computing LOOP 843
# ---------------------------
# Computing LOOP 844
# ---------------------------
# Computing LOOP 845
# ---------------------------
# Computing LOOP 846
# ---------------------------
# Computing LOOP 847
# ---------------------------
# Computing LOOP 848
# ---------------------------
# Computing LOOP 849
# ---------------------------
# Computing LOOP 850
# ---------------------------
# Computing LOOP 851
# ---------------------------
# Computing LOOP 852
# ---------------------------
# Computing LOOP 853
# ---------------------------
# Computing LOOP 854
# ---------------------------
# Computing LOOP 855
# ---------------------------
# Computing LOOP 856
# ---------------------------
# Computing LOOP 857
# ---------------------------
# Computing LOOP 858
# ---------------------------
# Computing LOOP 859
# ---------------------------
# Computing LOOP 860
# ---------------------------
# Computing LOOP 861
# ---------------------------
# Computing LOOP 862
# ---------------------------
# Computing LOOP 863
# ---------------------------
# Computing LOOP 864
# ---------------------------
# Computing LOOP 865
# ---------------------------
# Computing LOOP 866
# ---------------------------
# Computing LOOP 867
# ---------------------------
# Computing LOOP 868
# ---------------------------
# Computing LOOP 869
# ---------------------------
# Computing LOOP 870
# ---------------------------
# Computing LOOP 871
# ---------------------------
# Computing LOOP 872
# ---------------------------
# Computing LOOP 873
# ---------------------------
# Computing LOOP 874
# ---------------------------
# Computing LOOP 875
# ---------------------------
# Computing LOOP 876
# ---------------------------
# Computing LOOP 877
# ---------------------------
# Computing LOOP 878
# ---------------------------
# Computing LOOP 879
# ---------------------------
# Computing LOOP 880
# ---------------------------
# Computing LOOP 881
# ---------------------------
# Computing LOOP 882
# ---------------------------
# Computing LOOP 883
# ---------------------------
# Computing LOOP 884
# ---------------------------
# Computing LOOP 885
# ---------------------------
# Computing LOOP 886
# ---------------------------
# Computing LOOP 887
# ---------------------------
# Computing LOOP 888
# ---------------------------
# Computing LOOP 889
# ---------------------------
# Computing LOOP 890
# ---------------------------
# Computing LOOP 891
# ---------------------------
# Computing LOOP 892
# ---------------------------
# Computing LOOP 893
# ---------------------------
# Computing LOOP 894
# ---------------------------
# Computing LOOP 895
# ---------------------------
# Computing LOOP 896
# ---------------------------
# Computing LOOP 897
# ---------------------------
# Computing LOOP 898
# ---------------------------
# Computing LOOP 899
# ---------------------------
# Computing LOOP 900
# ---------------------------
# Computing LOOP 901
# ---------------------------
# Computing LOOP 902
# ---------------------------
# Computing LOOP 903
# ---------------------------
# Computing LOOP 904
# ---------------------------
# Computing LOOP 905
# ---------------------------
# Computing LOOP 906
# ---------------------------
# Computing LOOP 907
# ---------------------------
# Computing LOOP 908
# ---------------------------
# Computing LOOP 909
# ---------------------------
# Computing LOOP 910
# ---------------------------
# Computing LOOP 911
# ---------------------------
# Computing LOOP 912
# ---------------------------
# Computing LOOP 913
# ---------------------------
# Computing LOOP 914
# ---------------------------
# Computing LOOP 915
# ---------------------------
# Computing LOOP 916
# ---------------------------
# Computing LOOP 917
# ---------------------------
# Computing LOOP 918
# ---------------------------
# Computing LOOP 919
# ---------------------------
# Computing LOOP 920
# ---------------------------
# Computing LOOP 921
# ---------------------------
# Computing LOOP 922
# ---------------------------
# Computing LOOP 923
# ---------------------------
# Computing LOOP 924
# ---------------------------
# Computing LOOP 925
# ---------------------------
# Computing LOOP 926
# ---------------------------
# Computing LOOP 927
# ---------------------------
# Computing LOOP 928
# ---------------------------
# Computing LOOP 929
# ---------------------------
# Computing LOOP 930
# ---------------------------
# Computing LOOP 931
# ---------------------------
# Computing LOOP 932
# ---------------------------
# Computing LOOP 933
# ---------------------------
# Computing LOOP 934
# ---------------------------
# Computing LOOP 935
# ---------------------------
# Computing LOOP 936
# ---------------------------
# Computing LOOP 937
# ---------------------------
# Computing LOOP 938
# ---------------------------
# Computing LOOP 939
# ---------------------------
# Computing LOOP 940
# ---------------------------
# Computing LOOP 941
# ---------------------------
# Computing LOOP 942
# ---------------------------
# Computing LOOP 943
# ---------------------------
# Computing LOOP 944
# ---------------------------
# Computing LOOP 945
# ---------------------------
# Computing LOOP 946
# ---------------------------
# Computing LOOP 947
# ---------------------------
# Computing LOOP 948
# ---------------------------
# Computing LOOP 949
# ---------------------------
# Computing LOOP 950
# ---------------------------
# Computing LOOP 951
# ---------------------------
# Computing LOOP 952
# ---------------------------
# Computing LOOP 953
# ---------------------------
# Computing LOOP 954
# ---------------------------
# Computing LOOP 955
# ---------------------------
# Computing LOOP 956
# ---------------------------
# Computing LOOP 957
# ---------------------------
# Computing LOOP 958
# ---------------------------
# Computing LOOP 959
# ---------------------------
# Computing LOOP 960
# ---------------------------
# Computing LOOP 961
# ---------------------------
# Computing LOOP 962
# ---------------------------
# Computing LOOP 963
# ---------------------------
# Computing LOOP 964
# ---------------------------
# Computing LOOP 965
# ---------------------------
# Computing LOOP 966
# ---------------------------
# Computing LOOP 967
# ---------------------------
# Computing LOOP 968
# ---------------------------
# Computing LOOP 969
# ---------------------------
# Computing LOOP 970
# ---------------------------
# Computing LOOP 971
# ---------------------------
# Computing LOOP 972
# ---------------------------
# Computing LOOP 973
# ---------------------------
# Computing LOOP 974
# ---------------------------
# Computing LOOP 975
# ---------------------------
# Computing LOOP 976
# ---------------------------
# Computing LOOP 977
# ---------------------------
# Computing LOOP 978
# ---------------------------
# Computing LOOP 979
# ---------------------------
# Computing LOOP 980
# ---------------------------
# Computing LOOP 981
# ---------------------------
# Computing LOOP 982
# ---------------------------
# Computing LOOP 983
# ---------------------------
# Computing LOOP 984
# ---------------------------
# Computing LOOP 985
# ---------------------------
# Computing LOOP 986
# ---------------------------
# Computing LOOP 987
# ---------------------------
# Computing LOOP 988
# ---------------------------
# Computing LOOP 989
# ---------------------------
# Computing LOOP 990
# ---------------------------
# Computing LOOP 991
# ---------------------------
# Computing LOOP 992
# ---------------------------
# Computing LOOP 993
# ---------------------------
# Computing LOOP 994
# ---------------------------
# Computing LOOP 995
# ---------------------------
# Computing LOOP 996
# ---------------------------
# Computing LOOP 997
# ---------------------------
# Computing LOOP 998
# ---------------------------
# Computing LOOP 999
# ---------------------------
# Computing LOOP 1000
# ---------------------------
# Computing LOOP 1001
# ---------------------------
# Computing LOOP 1002
# ---------------------------
# Computing LOOP 1003
# ---------------------------
# Computing LOOP 1004
# ---------------------------
# Computing LOOP 1005
# ---------------------------
# Computing LOOP 1006
# ---------------------------
# Computing LOOP 1007
# ---------------------------
# Computing LOOP 1008
# ---------------------------
# Computing LOOP 1009
# ---------------------------
# Computing LOOP 1010
# ---------------------------
# Computing LOOP 1011
# ---------------------------
# Computing LOOP 1012
# ---------------------------
# Computing LOOP 1013
# ---------------------------
# Computing LOOP 1014
# ---------------------------
# Computing LOOP 1015
# ---------------------------
# Computing LOOP 1016
# ---------------------------
# Computing LOOP 1017
# ---------------------------
# Computing LOOP 1018
# ---------------------------
# Computing LOOP 1019
# ---------------------------
# Computing LOOP 1020
# ---------------------------
# Computing LOOP 1021
# ---------------------------
# Computing LOOP 1022
# ...
# ---------------------------
# Computing LOOP 4667
# ---------------------------
# Computing LOOP 4668
# ---------------------------
# Computing LOOP 4669
# ---------------------------
# Computing LOOP 4670
# ---------------------------
# Computing LOOP 4671
# ---------------------------
# Computing LOOP 4672
# ---------------------------
# Computing LOOP 4673
# ---------------------------
# Computing LOOP 4674
# ---------------------------
# Computing LOOP 4675
# ---------------------------
# Computing LOOP 4676
# ---------------------------
# Computing LOOP 4677
# ---------------------------
# Computing LOOP 4678
# ---------------------------
# Computing LOOP 4679
# ---------------------------
# Computing LOOP 4680
# ---------------------------
# Computing LOOP 4681
# ---------------------------
# Computing LOOP 4682
# ---------------------------
# Computing LOOP 4683
# ---------------------------
# Computing LOOP 4684
# ---------------------------
# Computing LOOP 4685
# ---------------------------
# Computing LOOP 4686
# ---------------------------
# Computing LOOP 4687
# ---------------------------
# Computing LOOP 4688
# ---------------------------
# Computing LOOP 4689
# ---------------------------
# Computing LOOP 4690
# ---------------------------
# Computing LOOP 4691
# ---------------------------
# Computing LOOP 4692
# ---------------------------
# Computing LOOP 4693
# ---------------------------
# Computing LOOP 4694
# ---------------------------
# Computing LOOP 4695
# ---------------------------
# Computing LOOP 4696
# ---------------------------
# Computing LOOP 4697
# ---------------------------
# Computing LOOP 4698
# ---------------------------
# Computing LOOP 4699
# ---------------------------
# Computing LOOP 4700
# ---------------------------
# Computing LOOP 4701
# ---------------------------
# Computing LOOP 4702
# ---------------------------
# Computing LOOP 4703
# ---------------------------
# Computing LOOP 4704
# ---------------------------
# Computing LOOP 4705
# ---------------------------
# Computing LOOP 4706
# ---------------------------
# Computing LOOP 4707
# ---------------------------
# Computing LOOP 4708
# ---------------------------
# Computing LOOP 4709
# ---------------------------
# Computing LOOP 4710
# ---------------------------
# Computing LOOP 4711
# ---------------------------
# Computing LOOP 4712
# ---------------------------
# Computing LOOP 4713
# ---------------------------
# Computing LOOP 4714
# ---------------------------
# Computing LOOP 4715
# ---------------------------
# Computing LOOP 4716
# ---------------------------
# Computing LOOP 4717
# ---------------------------
# Computing LOOP 4718
# ---------------------------
# Computing LOOP 4719
# ---------------------------
# Computing LOOP 4720
# ---------------------------
# Computing LOOP 4721
# ---------------------------
# Computing LOOP 4722
# ---------------------------
# Computing LOOP 4723
# ---------------------------
# Computing LOOP 4724
# ---------------------------
# Computing LOOP 4725
# ---------------------------
# Computing LOOP 4726
# ---------------------------
# Computing LOOP 4727
# ---------------------------
# Computing LOOP 4728
# ---------------------------
# Computing LOOP 4729
# ---------------------------
# Computing LOOP 4730
# ---------------------------
# Computing LOOP 4731
# ---------------------------
# Computing LOOP 4732
# ---------------------------
# Computing LOOP 4733
# ---------------------------
# Computing LOOP 4734
# ---------------------------
# Computing LOOP 4735
# ---------------------------
# Computing LOOP 4736
# ---------------------------
# Computing LOOP 4737
# ---------------------------
# Computing LOOP 4738
# ---------------------------
# Computing LOOP 4739
# ---------------------------
# Computing LOOP 4740
# ---------------------------
# Computing LOOP 4741
# ---------------------------
# Computing LOOP 4742
# ---------------------------
# Computing LOOP 4743
# ---------------------------
# Computing LOOP 4744
# ---------------------------
# Computing LOOP 4745
# ---------------------------
# Computing LOOP 4746
# ---------------------------
# Computing LOOP 4747
# ---------------------------
# Computing LOOP 4748
# ---------------------------
# Computing LOOP 4749
# ---------------------------
# Computing LOOP 4750
# ---------------------------
# Computing LOOP 4751
# ---------------------------
# Computing LOOP 4752
# ---------------------------
# Computing LOOP 4753
# ---------------------------
# Computing LOOP 4754
# ---------------------------
# Computing LOOP 4755
# ---------------------------
# Computing LOOP 4756
# ---------------------------
# Computing LOOP 4757
# ---------------------------
# Computing LOOP 4758
# ---------------------------
# Computing LOOP 4759
# ---------------------------
# Computing LOOP 4760
# ---------------------------
# Computing LOOP 4761
# ---------------------------
# Computing LOOP 4762
# ---------------------------
# Computing LOOP 4763
# ---------------------------
# Computing LOOP 4764
# ---------------------------
# Computing LOOP 4765
# ---------------------------
# Computing LOOP 4766
# ---------------------------
# Computing LOOP 4767
# ---------------------------
# Computing LOOP 4768
# ---------------------------
# Computing LOOP 4769
# ---------------------------
# Computing LOOP 4770
# ---------------------------
# Computing LOOP 4771
# ---------------------------
# Computing LOOP 4772
# ---------------------------
# Computing LOOP 4773
# ---------------------------
# Computing LOOP 4774
# ---------------------------
# Computing LOOP 4775
# ---------------------------
# Computing LOOP 4776
# ---------------------------
# Computing LOOP 4777
# ---------------------------
# Computing LOOP 4778
# ---------------------------
# Computing LOOP 4779
# ---------------------------
# Computing LOOP 4780
# ---------------------------
# Computing LOOP 4781
# ---------------------------
# Computing LOOP 4782
# ---------------------------
# Computing LOOP 4783
# ---------------------------
# Computing LOOP 4784
# ---------------------------
# Computing LOOP 4785
# ---------------------------
# Computing LOOP 4786
# ---------------------------
# Computing LOOP 4787
# ---------------------------
# Computing LOOP 4788
# ---------------------------
# Computing LOOP 4789
# ---------------------------
# Computing LOOP 4790
# ---------------------------
# Computing LOOP 4791
# ---------------------------
# Computing LOOP 4792
# ---------------------------
# Computing LOOP 4793
# ---------------------------
# Computing LOOP 4794
# ---------------------------
# Computing LOOP 4795
# ---------------------------
# Computing LOOP 4796
# ---------------------------
# Computing LOOP 4797
# ---------------------------
# Computing LOOP 4798
# ---------------------------
# Computing LOOP 4799
# ---------------------------
# Computing LOOP 4800
# ---------------------------
# Computing LOOP 4801
# ---------------------------
# Computing LOOP 4802
# ---------------------------
# Computing LOOP 4803
# ---------------------------
# Computing LOOP 4804
# ---------------------------
# Computing LOOP 4805
# ---------------------------
# Computing LOOP 4806
# ---------------------------
# Computing LOOP 4807
# ---------------------------
# Computing LOOP 4808
# ---------------------------
# Computing LOOP 4809
# ---------------------------
# Computing LOOP 4810
# ---------------------------
# Computing LOOP 4811
# ---------------------------
# Computing LOOP 4812
# ---------------------------
# Computing LOOP 4813
# ---------------------------
# Computing LOOP 4814
# ---------------------------
# Computing LOOP 4815
# ---------------------------
# Computing LOOP 4816
# ---------------------------
# Computing LOOP 4817
# ---------------------------
# Computing LOOP 4818
# ---------------------------
# Computing LOOP 4819
# ---------------------------
# Computing LOOP 4820
# ---------------------------
# Computing LOOP 4821
# ---------------------------
# Computing LOOP 4822
# ---------------------------
# Computing LOOP 4823
# ---------------------------
# Computing LOOP 4824
# ---------------------------
# Computing LOOP 4825
# ---------------------------
# Computing LOOP 4826
# ---------------------------
# Computing LOOP 4827
# ---------------------------
# Computing LOOP 4828
# ---------------------------
# Computing LOOP 4829
# ---------------------------
# Computing LOOP 4830
# ---------------------------
# Computing LOOP 4831
# ---------------------------
# Computing LOOP 4832
# ---------------------------
# Computing LOOP 4833
# ---------------------------
# Computing LOOP 4834
# ---------------------------
# Computing LOOP 4835
# ---------------------------
# Computing LOOP 4836
# ---------------------------
# Computing LOOP 4837
# ---------------------------
# Computing LOOP 4838
# ---------------------------
# Computing LOOP 4839
# ---------------------------
# Computing LOOP 4840
# ---------------------------
# Computing LOOP 4841
# ---------------------------
# Computing LOOP 4842
# ---------------------------
# Computing LOOP 4843
# ---------------------------
# Computing LOOP 4844
# ---------------------------
# Computing LOOP 4845
# ---------------------------
# Computing LOOP 4846
# ---------------------------
# Computing LOOP 4847
# ---------------------------
# Computing LOOP 4848
# ---------------------------
# Computing LOOP 4849
# ---------------------------
# Computing LOOP 4850
# ---------------------------
# Computing LOOP 4851
# ---------------------------
# Computing LOOP 4852
# ---------------------------
# Computing LOOP 4853
# ---------------------------
# Computing LOOP 4854
# ---------------------------
# Computing LOOP 4855
# ---------------------------
# Computing LOOP 4856
# ---------------------------
# Computing LOOP 4857
# ---------------------------
# Computing LOOP 4858
# ---------------------------
# Computing LOOP 4859
# ---------------------------
# Computing LOOP 4860
# ---------------------------
# Computing LOOP 4861
# ---------------------------
# Computing LOOP 4862
# ---------------------------
# Computing LOOP 4863
# ---------------------------
# Computing LOOP 4864
# ---------------------------
# Computing LOOP 4865
# ---------------------------
# Computing LOOP 4866
# ---------------------------
# Computing LOOP 4867
# ---------------------------
# Computing LOOP 4868
# ---------------------------
# Computing LOOP 4869
# ---------------------------
# Computing LOOP 4870
# ---------------------------
# Computing LOOP 4871
# ---------------------------
# Computing LOOP 4872
# ---------------------------
# Computing LOOP 4873
# ---------------------------
# Computing LOOP 4874
# ---------------------------
# Computing LOOP 4875
# ---------------------------
# Computing LOOP 4876
# ---------------------------
# Computing LOOP 4877
# ---------------------------
# Computing LOOP 4878
# ---------------------------
# Computing LOOP 4879
# ---------------------------
# Computing LOOP 4880
# ---------------------------
# Computing LOOP 4881
# ---------------------------
# Computing LOOP 4882
# ---------------------------
# Computing LOOP 4883
# ---------------------------
# Computing LOOP 4884
# ---------------------------
# Computing LOOP 4885
# ---------------------------
# Computing LOOP 4886
# ---------------------------
# Computing LOOP 4887
# ---------------------------
# Computing LOOP 4888
# ---------------------------
# Computing LOOP 4889
# ---------------------------
# Computing LOOP 4890
# ---------------------------
# Computing LOOP 4891
# ---------------------------
# Computing LOOP 4892
# ---------------------------
# Computing LOOP 4893
# ---------------------------
# Computing LOOP 4894
# ---------------------------
# Computing LOOP 4895
# ---------------------------
# Computing LOOP 4896
# ---------------------------
# Computing LOOP 4897
# ---------------------------
# Computing LOOP 4898
# ---------------------------
# Computing LOOP 4899
# ---------------------------
# Computing LOOP 4900
# ---------------------------
# Computing LOOP 4901
# ---------------------------
# Computing LOOP 4902
# ---------------------------
# Computing LOOP 4903
# ---------------------------
# Computing LOOP 4904
# ---------------------------
# Computing LOOP 4905
# ---------------------------
# Computing LOOP 4906
# ---------------------------
# Computing LOOP 4907
# ---------------------------
# Computing LOOP 4908
# ---------------------------
# Computing LOOP 4909
# ---------------------------
# Computing LOOP 4910
# ---------------------------
# Computing LOOP 4911
# ---------------------------
# Computing LOOP 4912
# ---------------------------
# Computing LOOP 4913
# ---------------------------
# Computing LOOP 4914
# ---------------------------
# Computing LOOP 4915
# ---------------------------
# Computing LOOP 4916
# ---------------------------
# Computing LOOP 4917
# ---------------------------
# Computing LOOP 4918
# ---------------------------
# Computing LOOP 4919
# ---------------------------
# Computing LOOP 4920
# ---------------------------
# Computing LOOP 4921
# ---------------------------
# Computing LOOP 4922
# ---------------------------
# Computing LOOP 4923
# ---------------------------
# Computing LOOP 4924
# ---------------------------
# Computing LOOP 4925
# ---------------------------
# Computing LOOP 4926
# ---------------------------
# Computing LOOP 4927
# ---------------------------
# Computing LOOP 4928
# ---------------------------
# Computing LOOP 4929
# ---------------------------
# Computing LOOP 4930
# ---------------------------
# Computing LOOP 4931
# ---------------------------
# Computing LOOP 4932
# ---------------------------
# Computing LOOP 4933
# ---------------------------
# Computing LOOP 4934
# ---------------------------
# Computing LOOP 4935
# ---------------------------
# Computing LOOP 4936
# ---------------------------
# Computing LOOP 4937
# ---------------------------
# Computing LOOP 4938
# ---------------------------
# Computing LOOP 4939
# ---------------------------
# Computing LOOP 4940
# ---------------------------
# Computing LOOP 4941
# ---------------------------
# Computing LOOP 4942
# ---------------------------
# Computing LOOP 4943
# ---------------------------
# Computing LOOP 4944
# ---------------------------
# Computing LOOP 4945
# ---------------------------
# Computing LOOP 4946
# ---------------------------
# Computing LOOP 4947
# ---------------------------
# Computing LOOP 4948
# ---------------------------
# Computing LOOP 4949
# ---------------------------
# Computing LOOP 4950
# ---------------------------
# Computing LOOP 4951
# ---------------------------
# Computing LOOP 4952
# ---------------------------
# Computing LOOP 4953
# ---------------------------
# Computing LOOP 4954
# ---------------------------
# Computing LOOP 4955
# ---------------------------
# Computing LOOP 4956
# ---------------------------
# Computing LOOP 4957
# ---------------------------
# Computing LOOP 4958
# ---------------------------
# Computing LOOP 4959
# ---------------------------
# Computing LOOP 4960
# ---------------------------
# Computing LOOP 4961
# ---------------------------
# Computing LOOP 4962
# ---------------------------
# Computing LOOP 4963
# ---------------------------
# Computing LOOP 4964
# ---------------------------
# Computing LOOP 4965
# ---------------------------
# Computing LOOP 4966
# ---------------------------
# Computing LOOP 4967
# ---------------------------
# Computing LOOP 4968
# ---------------------------
# Computing LOOP 4969
# ---------------------------
# Computing LOOP 4970
# ---------------------------
# Computing LOOP 4971
# ---------------------------
# Computing LOOP 4972
# ---------------------------
# Computing LOOP 4973
# ---------------------------
# Computing LOOP 4974
# ---------------------------
# Computing LOOP 4975
# ---------------------------
# Computing LOOP 4976
# ---------------------------
# Computing LOOP 4977
# ---------------------------
# Computing LOOP 4978
# ---------------------------
# Computing LOOP 4979
# ---------------------------
# Computing LOOP 4980
# ---------------------------
# Computing LOOP 4981
# ---------------------------
# Computing LOOP 4982
# ---------------------------
# Computing LOOP 4983
# ---------------------------
# Computing LOOP 4984
# ---------------------------
# Computing LOOP 4985
# ---------------------------
# Computing LOOP 4986
# ---------------------------
# Computing LOOP 4987
# ---------------------------
# Computing LOOP 4988
# ---------------------------
# Computing LOOP 4989
# ---------------------------
# Computing LOOP 4990
# ---------------------------
# Computing LOOP 4991
# ---------------------------
# Computing LOOP 4992
# ---------------------------
# Computing LOOP 4993
# ---------------------------
# Computing LOOP 4994
# ---------------------------
# Computing LOOP 4995
# ---------------------------
# Computing LOOP 4996
# ---------------------------
# Computing LOOP 4997
# ---------------------------
# Computing LOOP 4998
# ---------------------------
# Computing LOOP 4999

# %%
all_gcsm_1000 = []

for i in range(n_loop):
    if i%100==0:
        print("Computing loop ", i)
    sys.gen_channels(is_los=is_los)
    sys.run_GCSM(N_samples=1000)
    gcsm = 10 * np.log10(sys.cal_snr())

    all_gcsm_1000.append(gcsm)
# Out:
# Computing loop  0
# Computing loop  100
# Computing loop  200
# Computing loop  300
# Computing loop  400
# Computing loop  500
# Computing loop  600
# Computing loop  700
# Computing loop  800
# Computing loop  900
# Computing loop  1000
# Computing loop  1100
# Computing loop  1200
# Computing loop  1300
# Computing loop  1400
# Computing loop  1500
# Computing loop  1600
# Computing loop  1700
# Computing loop  1800
# Computing loop  1900
# Computing loop  2000
# Computing loop  2100
# Computing loop  2200
# Computing loop  2300
# Computing loop  2400
# Computing loop  2500
# Computing loop  2600
# Computing loop  2700
# Computing loop  2800
# Computing loop  2900
# Computing loop  3000
# Computing loop  3100
# Computing loop  3200
# Computing loop  3300
# Computing loop  3400
# Computing loop  3500
# Computing loop  3600
# Computing loop  3700
# Computing loop  3800
# Computing loop  3900
# Computing loop  4000
# Computing loop  4100
# Computing loop  4200
# Computing loop  4300
# Computing loop  4400
# Computing loop  4500
# Computing loop  4600
# Computing loop  4700
# Computing loop  4800
# Computing loop  4900

# %%
all_gcsm_3000 = []

for i in range(n_loop):
    if i%100==0:
        print("Computing loop ", i)
    sys.gen_channels(is_los=is_los)
    sys.run_GCSM(N_samples=3000)
    gcsm = 10 * np.log10(sys.cal_snr())

    all_gcsm_3000.append(gcsm)
# Out:
# Computing loop  0
# Computing loop  100
# Computing loop  200
# Computing loop  300
# Computing loop  400
# Computing loop  500
# Computing loop  600
# Computing loop  700
# Computing loop  800
# Computing loop  900
# Computing loop  1000
# Computing loop  1100
# Computing loop  1200
# Computing loop  1300
# Computing loop  1400
# Computing loop  1500
# Computing loop  1600
# Computing loop  1700
# Computing loop  1800
# Computing loop  1900
# Computing loop  2000
# Computing loop  2100
# Computing loop  2200
# Computing loop  2300
# Computing loop  2400
# Computing loop  2500
# Computing loop  2600
# Computing loop  2700
# Computing loop  2800
# Computing loop  2900
# Computing loop  3000
# Computing loop  3100
# Computing loop  3200
# Computing loop  3300
# Computing loop  3400
# Computing loop  3500
# Computing loop  3600
# Computing loop  3700
# Computing loop  3800
# Computing loop  3900
# Computing loop  4000
# Computing loop  4100
# Computing loop  4200
# Computing loop  4300
# Computing loop  4400
# Computing loop  4500
# Computing loop  4600
# Computing loop  4700
# Computing loop  4800
# Computing loop  4900

# %%
all_perfect = []

for i in range(n_loop):
    if i%100==0:
        print("Computing loop ", i)
    sys.gen_channels(is_los=is_los)

    # Perfect_csi
    sys.ris.theta, sys.ris.vector_x = opt.perfect_csi(h_0=sys.h_0, h_=sys.h)
    perfect_csi = 10 * np.log10(sys.cal_snr())
    
    all_perfect.append(perfect_csi)
# Out:
# Computing loop  0
# Computing loop  100
# Computing loop  200
# Computing loop  300
# Computing loop  400
# Computing loop  500
# Computing loop  600
# Computing loop  700
# Computing loop  800
# Computing loop  900
# Computing loop  1000
# Computing loop  1100
# Computing loop  1200
# Computing loop  1300
# Computing loop  1400
# Computing loop  1500
# Computing loop  1600
# Computing loop  1700
# Computing loop  1800
# Computing loop  1900
# Computing loop  2000
# Computing loop  2100
# Computing loop  2200
# Computing loop  2300
# Computing loop  2400
# Computing loop  2500
# Computing loop  2600
# Computing loop  2700
# Computing loop  2800
# Computing loop  2900
# Computing loop  3000
# Computing loop  3100
# Computing loop  3200
# Computing loop  3300
# Computing loop  3400
# Computing loop  3500
# Computing loop  3600
# Computing loop  3700
# Computing loop  3800
# Computing loop  3900
# Computing loop  4000
# Computing loop  4100
# Computing loop  4200
# Computing loop  4300
# Computing loop  4400
# Computing loop  4500
# Computing loop  4600
# Computing loop  4700
# Computing loop  4800
# Computing loop  4900

# %%
def plot_multiple_cdfs(data_lists, labels):
    """
    Plots the Cumulative Distribution Functions (CDFs) of multiple lists of values on the same plot.
    
    Parameters:
    data_lists (list of lists): A list containing multiple lists of numerical values.
    labels (list of str, optional): Labels for each CDF in the legend. If None, uses default labels for specific use case.
    """
    colors = ['#B71C1C', '#039BE5', '#26A69A', '#FF6F00', '#616161', '#BA68C8', '#EC407A']
    plt.figure(figsize=(3.5, 2.625), dpi=500)
    #Font setup
    plt.rcParams['font.family'] = 'Helvetica'
    plt.rcParams['mathtext.fontset'] = 'dejavuserif'
    plt.rcParams['text.usetex'] = False
    plt.rcParams['font.size'] = 7
    plt.rcParams['legend.fontsize'] = 7

    plt.rcParams['xtick.minor.visible'] = False
    plt.rcParams['ytick.minor.visible'] = False
    plt.rcParams['xtick.direction'] = 'in'
    plt.rcParams['ytick.direction'] = 'in'
    plt.rcParams['xtick.major.width'] = 0.3
    plt.rcParams['ytick.major.width'] = 0.3
    plt.rcParams['axes.linewidth'] = 0.3
    
    for i, x in enumerate(data_lists):
        # Sort the data
        sorted_x = np.sort(x)
        # Compute the CDF values
        y = np.arange(1, len(x) + 1) / len(x)
        # Plot the CDF
        if labels[i] == 'BORN':
            plt.plot(sorted_x, y, drawstyle='steps-post', label=labels[i], ls='-.', color=colors[i], linewidth=1.0)
        elif labels[i] == 'Optimal':
            plt.plot(sorted_x, y, drawstyle='steps-post', label=labels[i], ls=':', color=colors[i], linewidth=1.0)
        else:
            plt.plot(sorted_x, y, drawstyle='steps-post', label=labels[i], color=colors[i], linewidth=1.0)
    
    plt.ylabel('CDF')
    plt.xlabel('Received SNR (dB)')
    plt.xlim([5, 25])
    plt.xticks([5, 10, 15, 20, 25])
    plt.ylim([0, 1])
    leg = plt.legend(frameon=False, edgecolor='black', framealpha=0.8,
                 fontsize=7, handlelength=2, handletextpad=0.5, labelspacing=0.55)
    leg.get_frame().set_linewidth(0.4)
    plt.grid(color='gainsboro', linestyle='--', linewidth=0.2)
    plt.savefig(figure_name, dpi=500, bbox_inches='tight', pad_inches=0.05)


plot_multiple_cdfs([all_born_1000, all_born_3000, all_gcsm_1000, all_gcsm_3000, all_perfect], labels=[r'BORN: $N_s = 1000$', r'BORN: $N_s = 3000$', r'GCSM: $N_s = 1000$', r'GCSM: $N_s=3000$', r'Optimal'])
